# %%
import nltk
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('omw-1.4')
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from ast import literal_eval
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
data = pd.read_csv("chatgpt.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                              reviewId       userName  \
# 0           0  1f4cfa28-6dd4-4e39-a088-866d07b7f882     José Pérez
# 1           1  9d692923-faa8-4ff0-887b-4274a3ea38bf  Steve Gilbert
# 2           2  8bd66c82-ff65-43ae-9a17-83dac0364ae7            kay
# 3           3  b70c67e6-7052-43c8-86ea-1419ffff2ec7  Aviral Sharma
# 4           4  e8a2aa7d-46fc-4975-a1a4-d9c9da78d244      R Meowing
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  It stopped working, it loads for a little bit....      1              3
# 1  I've not been able to run this app so my revie...      1              5
# 2  It's surprising how bad the app is compared to...      1            145
# 3  A colossal waste of time. Somehow, the prompts...      1              6
# 4  It looks cool but it just doesn't work on my p...      1             11
#
#   reviewCreatedVersion                at replyContent repliedAt  appVersion  \
# 0           1.2023.281  16-10-2023 15:14          NaN       NaN  1.2023.281
# 1           1.2023.243  16-09-2023 22:32          NaN       NaN  1.2023.243
# 2             1.0.0026  06-08-2023 01:47          NaN       NaN    1.0.0026
# 3           1.2023.263  11-10-2023 12:28          NaN       NaN  1.2023.263
# 4           1.2023.263  04-10-2023 22:08          NaN       NaN  1.2023.263
#
#        sortOrder               appId
# 0  most_relevant  com.openai.chatgpt
# 1  most_relevant  com.openai.chatgpt
# 2  most_relevant  com.openai.chatgpt
# 3  most_relevant  com.openai.chatgpt
# 4  most_relevant  com.openai.chatgpt

# %%
data.drop(['userImage','score','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt','appVersion','appId'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0                              reviewId       userName  \
# 0           0  1f4cfa28-6dd4-4e39-a088-866d07b7f882     José Pérez
# 1           1  9d692923-faa8-4ff0-887b-4274a3ea38bf  Steve Gilbert
# 2           2  8bd66c82-ff65-43ae-9a17-83dac0364ae7            kay
# 3           3  b70c67e6-7052-43c8-86ea-1419ffff2ec7  Aviral Sharma
# 4           4  e8a2aa7d-46fc-4975-a1a4-d9c9da78d244      R Meowing
#
#                                              content                at  \
# 0  It stopped working, it loads for a little bit....  16-10-2023 15:14
# 1  I've not been able to run this app so my revie...  16-09-2023 22:32
# 2  It's surprising how bad the app is compared to...  06-08-2023 01:47
# 3  A colossal waste of time. Somehow, the prompts...  11-10-2023 12:28
# 4  It looks cool but it just doesn't work on my p...  04-10-2023 22:08
#
#        sortOrder
# 0  most_relevant
# 1  most_relevant
# 2  most_relevant
# 3  most_relevant
# 4  most_relevant
